# %% [markdown]
# https://docs.llamaindex.ai/en/stable/examples/llm/bedrock/

# %%
# %pip install llama-index-llms-bedrock
# Out:
# Collecting llama-index-llms-bedrock
#   Downloading llama_index_llms_bedrock-0.2.1-py3-none-any.whl.metadata (738 bytes)
# Requirement already satisfied: boto3<2.0.0,>=1.34.26 in /opt/conda/lib/python3.11/site-packages (from llama-index-llms-bedrock) (1.35.24)
# Collecting llama-index-core<0.12.0,>=0.11.0 (from llama-index-llms-bedrock)
#   Downloading llama_index_core-0.11.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-llms-anthropic<0.3.0,>=0.2.0 (from llama-index-llms-bedrock)
#   Downloading llama_index_llms_anthropic-0.2.1-py3-none-any.whl.metadata (638 bytes)
# Requirement already satisfied: botocore<1.36.0,>=1.35.24 in /opt/conda/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.35.24)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (0.10.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2023.6.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (8.5.0)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock)
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.16.0)
# Collecting anthropic<0.29.0,>=0.26.2 (from llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock)
#   Downloading anthropic-0.28.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.9.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (1.9.0)
# Collecting jiter<1,>=0.4.0 (from anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock)
#   Downloading jiter-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /opt/conda/lib/python3.11/site-packages (from anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.36.0,>=1.35.24->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.36.0,>=1.35.24->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.26.19)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (3.21.3)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-bedrock) (24.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.24->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.16.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /opt/conda/lib/python3.11/site-packages (from tokenizers>=0.13.0->anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (0.24.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<0.29.0,>=0.26.2->llama-index-llms-anthropic<0.3.0,>=0.2.0->llama-index-llms-bedrock) (3.15.4)
# Downloading llama_index_llms_bedrock-0.2.1-py3-none-any.whl (8.5 kB)
# Downloading llama_index_core-0.11.11-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 89.2 MB/s eta 0:00:00
# Downloading llama_index_llms_anthropic-0.2.1-py3-none-any.whl (6.6 kB)
# Downloading anthropic-0.28.1-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.7/862.7 kB 77.6 MB/s eta 0:00:00
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 99.8 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: dirtyjson, jiter, tiktoken, llama-index-core, anthropic, llama-index-llms-anthropic, llama-index-llms-bedrock
# Successfully installed anthropic-0.28.1 dirtyjson-1.0.8 jiter-0.5.0 llama-index-core-0.11.11 llama-index-llms-anthropic-0.2.1 llama-index-llms-bedrock-0.2.1 tiktoken-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install llama-index
# Out:
# Collecting llama-index
#   Downloading llama_index-0.11.11-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.1 (from llama-index)
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.10 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.11.11)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl.metadata (686 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.3.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.9 (from llama-index)
#   Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl.metadata (648 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_readers_file-0.2.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index) (3.9.1)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading openai-1.47.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.10->llama-index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (2023.6.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.12.0,>=0.11.10->llama-index) (1.16.0)
# Collecting llama-cloud>=0.0.11 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index)
#   Downloading llama_cloud-0.0.17-py3-none-any.whl.metadata (751 bytes)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama-index)
#   Downloading llama_parse-0.5.6-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk>3.8.1->llama-index) (2024.7.24)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.10->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.10->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.5)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.10->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.10->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.10->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.10->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.26.19)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.10->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.10->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.10->llama-index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.10->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Downloading llama_index-0.11.11-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.3.1-py3-none-any.whl (10 kB)
# Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 95.5 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl (12 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.2.2-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Downloading llama_cloud-0.0.17-py3-none-any.whl (187 kB)
# Downloading llama_parse-0.5.6-py3-none-any.whl (10 kB)
# Downloading openai-1.47.0-py3-none-any.whl (375 kB)
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Installing collected packages: striprtf, pypdf, openai, llama-cloud, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed llama-cloud-0.0.17 llama-index-0.11.11 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.3.1 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.9 llama-index-multi-modal-llms-openai-0.2.1 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.2 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.6 openai-1.47.0 pypdf-4.3.1 striprtf-0.0.26

# %%
from llama_index.llms.bedrock import Bedrock

resp = Bedrock(
    model="amazon.titan-text-express-v1",
).complete("Star Trek is ")

# %%
print(resp)
# Out:
# an American media franchise based on the science fiction television series created by Gene Roddenberry. The first television series, Star Trek (1966–69), aired for three seasons on the original network, NBC, before moving to Paramount Pictures for the final two seasons and a subsequent film. The franchise has since expanded, including the launch of four spin-off television series, an additional eleven feature films, and further expansions in various media, including video games, comic books, novels, and theme park attractions.
#
# The franchise takes place in a future in which humanity has achieved faster-than-light space travel and colonized other planets and star systems. The main setting of the franchise is the United Federation of Planets, a fictional interstellar government that governs Earth and other inhabited planets. The franchise follows the adventures of the crew of the starship USS Enterprise, a futuristic spacecraft designed for interstellar exploration. The crew of the Enterprise includes Captain James T. Kirk, Commander Spock, Doctor Leonard "Bones" McCoy, and other characters who become iconic figures in popular culture.
#
# Star Trek has been praised for its innovative storytelling, its exploration of social and political issues, and its depiction of a diverse and inclusive future society. It has also been criticized for its portrayal of gender and racial stereotypes, and for its treatment of certain characters and storylines.
#
# The franchise has had a significant impact on popular culture, inspiring countless works of fiction, art, and media. It has also been used as a platform for social and political commentary, with episodes and films addressing issues such as racism, sexism, and environmentalism.
#
# Star Trek has a large and dedicated fan base, with numerous conventions and events held throughout the world each year. The franchise has also been adapted into various other media, including books, comics, and video games, and has been translated into numerous languages.
#
# In recent years, Star Trek has been rebooted with a new television series, Star Trek: Discovery (2017–present), which has received critical acclaim for its bold and innovative storytelling. The series has also introduced new characters and storylines, while retaining the core themes and values of the original franchise.
#
# Star Trek has also been used as a tool for education and outreach, with the franchise's educational programs and resources being used to teach science, technology, engineering, and mathematics (STEM) to students around the world.
#
# In conclusion, Star Trek is a beloved and iconic American media franchise that
